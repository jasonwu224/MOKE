# %%
import matplotlib.pyplot as plt 
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\gxlab\Code\MOKE\data\2025-07-14_16-06-29\H+_data.csv",comment='#')
df.head()
# Out:
#    Voltage (V)  Current (A)  Average Intensity  Total Intensity  SNR (dB)
# 0    -0.009998     0.000012        2842.154141         14068663  8.141005
# 1     4.989425     0.098328        2828.240404         13999790  8.218708
# 2     9.991507     0.196718        2826.089697         13989144  8.273630
# 3    14.992700     0.294941        2812.973737         13924220  8.144148
# 4    19.994750     0.392601        2822.262828         13970201  8.107935

# %%
plt.plot(df["Voltage (V)"], df["Average Intensity"])
plt.ylim((2800, 2850))
# Out:
# (2800.0, 2850.0)

# %%
plt.plot(df["Voltage (V)"][0:8], df["Average Intensity"][0:8])
plt.plot(df["Voltage (V)"][7:16], df["Average Intensity"][7:16], color="red")
plt.plot(-1*df["Voltage (V)"][15:24], df["Average Intensity"][15:24], color="green")
plt.plot(-1*df["Voltage (V)"][23:32], df["Average Intensity"][23:32], color="orange")

plt.ylim((2800, 2850))
# Out:
# (2800.0, 2850.0)
