# %%
import matplotlib.pyplot as plt 
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\gxlab\Code\MOKE\data\2025-07-15_15-49-24\H+_data.csv",comment='#')
df
# Out:
#     Voltage (V)  Current (A)  Average Intensity  Total Intensity  SNR (dB)
# 0     -0.009898     0.000017        2680.742444         12063341  8.978443
# 1      2.990138     0.054836        2679.016889         12055576  8.919091
# 2      5.989854     0.109749        2698.269778         12142214  8.965929
# 3      8.991606     0.164827        2687.544000         12093948  8.895398
# 4     11.992230     0.219989        2685.548222         12084967  8.884496
# ..          ...          ...                ...              ...       ...
# 58    23.995420     0.436901        2745.430222         12354436  8.940487
# 59    26.994950     0.491093        2745.583778         12355127  9.059908
# 60    29.993560     0.544738        2737.514444         12318815  8.974530
# 61    32.994130     0.598241        2744.814222         12351664  9.000057
# 62    35.994340     0.650850        2752.647111         12386912  9.018657
#
# [63 rows x 5 columns]

# %%
plt.plot(df["Voltage (V)"], df["Average Intensity"])
# plt.ylim((2800, 2850))

# %%
plt.plot(df["Voltage (V)"][0:13], df["Average Intensity"][0:13])
plt.plot(df["Voltage (V)"][12:25], df["Average Intensity"][12:25], color="red")
plt.plot(-1*df["Voltage (V)"][24:38], df["Average Intensity"][24:38], color="green")
plt.plot(-1*df["Voltage (V)"][37:50], df["Average Intensity"][37:50], color="orange")
plt.plot(df["Voltage (V)"][49:63], df["Average Intensity"][49:63], color="orange")
plt.grid(True)
# for i in range(0, 61, 12):
#     plt.plot(df["Voltage (V)"][i:i+12], df["Average Intensity"][i:i+12])

# %%
df = pd.read_csv(r"C:\Users\gxlab\Code\MOKE\data\2025-07-15_16-24-54\H+_data.csv",comment='#')
df
# Out:
#      Voltage (V)  Current (A)  Average Intensity  Total Intensity  SNR (dB)
# 0      -0.009998     0.000013        2760.082222         12420370  9.035362
# 1       0.490546     0.009577        2755.413778         12399362  8.931532
# 2       0.990121     0.019200        2733.213333         12299460  8.967462
# 3       1.489847     0.028793        2769.986444         12464939  8.977691
# 4       1.989762     0.038317        2749.757333         12373908  9.011241
# ..           ...          ...                ...              ...       ...
# 138     1.990126     0.037036        2755.819333         12401187  8.974579
# 139     1.490153     0.027752        2755.601111         12400205  9.008242
# 140     0.990662     0.018512        2742.218222         12339982  9.052269
# 141     0.490763     0.009358        2750.672444         12378026  8.932133
# 142    -0.009711     0.000018        2728.681333         12279066  9.022688
#
# [143 rows x 5 columns]

# %%
plt.plot(df["Voltage (V)"][0:73], df["Average Intensity"][0:73])
plt.plot(df["Voltage (V)"][72:143], df["Average Intensity"][72:143], color="red")

# %%
df = pd.read_csv(r"C:\Users\gxlab\Code\MOKE\data\2025-07-17_11-12-41\H+_data.csv", comment="#")
df
# Out:
#      Voltage (V)  Current (A)  Average Intensity  Total Intensity  SNR (dB)
# 0      -0.010029     0.000005           8.357143            49725  9.612224
# 1       0.490516     0.009655           8.360672            49746  9.644904
# 2       0.990262     0.019374           8.351597            49692  9.603061
# 3       1.489886     0.029061           8.307227            49428  9.699097
# 4       1.989751     0.038675           8.344538            49650  9.652668
# ..           ...          ...                ...              ...       ...
# 281     1.990224     0.032452           8.538992            50807  9.598941
# 282     1.490332     0.024868           8.526891            50735  9.556166
# 283     0.990666     0.016620           8.545882            50848  9.635772
# 284     0.491102     0.008440           8.532269            50767  9.597665
# 285    -0.009672     0.000024           8.515126            50665  9.598601
#
# [286 rows x 5 columns]

# %%
plt.plot(df["Voltage (V)"], df["Average Intensity"])

# %%
n = len(df["Voltage (V)"])
plt.plot(df["Voltage (V)"][0:n//2], df["Average Intensity"][0:n//2])
plt.plot(-1*df["Voltage (V)"][n//2:n], df["Average Intensity"][n//2:n], color="red")
plt.title("Voltage vs Average Intensity for S-Polarized Incident Light")
plt.xlabel("Voltage (V)")
plt.ylabel("Average Intensity (Counts)")
# Out:
# Text(0, 0.5, 'Average Intensity (Counts)')

# %%
df = pd.read_csv(r"C:\Users\gxlab\Code\MOKE\data\2025-07-17_11-38-43\H+_data.csv", comment="#")
df
# Out:
#      Voltage (V)  Current (A)  Average Intensity  Total Intensity  SNR (dB)
# 0      -0.010001     0.000019           8.537479            50798  9.444498
# 1       0.490614     0.008694           8.493109            50534  9.484772
# 2       0.990278     0.017241           8.486891            50497  9.512434
# 3       1.490025     0.025807           8.451429            50286  9.558755
# 4       1.989752     0.033671           8.478151            50445  9.501419
# ..           ...          ...                ...              ...       ...
# 353    33.495250     0.600361           8.402521            49995  9.523773
# 354    33.994900     0.608592           8.364370            49768  9.537861
# 355    34.495770     0.618582           8.368403            49792  9.517967
# 356    34.995580     0.626341           8.395126            49951  9.490634
# 357    35.495000     0.634017           8.380336            49863  9.518387
#
# [358 rows x 5 columns]

# %%
n = len(df["Voltage (V)"])
plt.plot(df["Voltage (V)"][0:2*n//5], df["Average Intensity"][0:2*n//5], label="Sweep 1")
plt.plot(-1*df["Voltage (V)"][2*n//5:4*n//5], df["Average Intensity"][2*n//5:4*n//5], label="Sweep 2")
plt.plot(df["Voltage (V)"][4*n//5:n], df["Average Intensity"][4*n//5:n], color="red", label="Sweep 3")
plt.legend()
plt.title("Voltage vs Average Intensity for S-Polarized Incident Light")
plt.xlabel("Voltage (V)")
plt.ylabel("Average Intensity (Counts)")
plt.gcf().text(0.5, -0.05, 'Figure 1: Hysteresis measurement using s-polarized light.\nThe analyzer is set 1 pm 0.5 degree clockwise off extinction.', ha='center', fontsize=10)
# Out:
# Text(0.5, -0.05, 'Figure 1: Hysteresis measurement using s-polarized light.\nThe analyzer is set 1 pm 0.5 degree clockwise off extinction.')

# %%
df = pd.read_csv(r"C:\Users\gxlab\Code\MOKE\data\2025-07-17_14-56-28\H+_data.csv", comment="#")
df
# Out:
#      Voltage (V)  Current (A)  Average Intensity  Total Intensity   SNR (dB)
# 0      -0.010159     0.000007           6.747733            50608   9.957298
# 1       0.490520     0.009765           6.757867            50684   9.977843
# 2       0.990297     0.019576           6.763467            50726  10.011707
# 3       1.489965     0.029364           6.742133            50566   9.968347
# 4       1.989816     0.039052           6.741467            50561  10.006923
# ..           ...          ...                ...              ...        ...
# 353    33.495270     0.604985           6.642533            49819  10.046836
# 354    33.994970     0.617244           6.674000            50055  10.029278
# 355    34.495600     0.624481           6.671200            50034  10.046481
# 356    34.995530     0.634574           6.657200            49929  10.047696
# 357    35.495000     0.642565           6.661467            49961  10.047941
#
# [358 rows x 5 columns]

# %%
fig, ax = plt.subplots()
ax.plot(df["Voltage (V)"], df["Average Intensity"])
ax.set_title("Average Intensity vs Applied Voltage for P-Polarized Incident Light")
ax.set_xlabel("Voltage (V)")
ax.set_ylabel("Average Intensity (Counts)")
fig.text(0.5, -0.05, 'Figure 2: Hysteresis measurement using p-polarized light.\nThe analyzer is set 1 pm 0.5 degree counterclockwise off extinction.', ha='center', fontsize=10)
# Out:
# Text(0.5, -0.05, 'Figure 2: Hysteresis measurement using p-polarized light.\nThe analyzer is set 1 pm 0.5 degree counterclockwise off extinction.')

# %%
df = pd.read_csv(r"C:\Users\gxlab\Code\MOKE\data\2025-07-17_15-42-59\H+_data.csv", comment="#")
df
# Out:
#      Voltage (V)  Current (A)  Average Intensity  Total Intensity  SNR (dB)
# 0      -0.009920     0.000002          19.488205           114006  8.077098
# 1       0.490738     0.009689          19.337949           113127  8.105761
# 2       0.990291     0.019464          19.349060           113192  8.106832
# 3       1.489954     0.029137          19.318803           113015  8.093692
# 4       1.989864     0.038920          19.333162           113099  8.113634
# ..           ...          ...                ...              ...       ...
# 353    33.495190     0.623620          19.765812           115630  8.097968
# 354    33.994850     0.632078          19.786496           115751  8.092909
# 355    34.495780     0.640437          19.907009           116456  8.089347
# 356    34.995470     0.648708          19.705812           115279  8.054916
# 357    35.495170     0.656959          19.751966           115549  8.045246
#
# [358 rows x 5 columns]

# %%
fig, ax = plt.subplots()
n = len(df["Voltage (V)"])
ax.plot(df["Voltage (V)"][0:2*n//5], df["Average Intensity"][0:2*n//5])
ax.plot(df["Voltage (V)"][2*n//5 - 1:n], df["Average Intensity"][2*n//5 - 1:n])
ax.set_title("Average Intensity vs Applied Voltage for P-Polarized Incident Light")
ax.set_xlabel("Voltage (V)")
ax.set_ylabel("Average Intensity (Counts)")
fig.text(0.5, -0.05, 'Figure 3: Hysteresis measurement using p-polarized light.\nThe analyzer is set 4 pm 0.5 degree counterclockwise off extinction.', ha='center', fontsize=10)
# Out:
# Text(0.5, -0.05, 'Figure 3: Hysteresis measurement using p-polarized light.\nThe analyzer is set 4 pm 0.5 degree counterclockwise off extinction.')

# %%
df_calibration = pd.read_csv(r"C:\Users\gxlab\Code\MOKE\data\calibration\Volts_to_Gauss_Calibration.csv")
df_calibration.head()
# Out:
#    Unnamed: 0  Magnetic Flux Density (G)  Voltage (V)  Current (A)
# 0           0                     -1.720    -0.009824     0.000004
# 1           1                      0.158     0.989776     0.019595
# 2           2                      2.050     1.989265     0.039186
# 3           3                      3.955     2.989733     0.058803
# 4           4                      5.867     3.989234     0.078356

# %%
from scipy.stats import linregress
volt = df_calibration["Voltage (V)"]
mag = df_calibration["Magnetic Flux Density (G)"]
slope, intercept, r_value, p_value, std_err = linregress(volt, mag)
print(slope, intercept, r_value, p_value, std_err)
fitted_mag = slope*volt+intercept
plt.scatter(volt, mag)
plt.plot(volt, fitted_mag, color="red", label=f"y = {slope:.2f}x{intercept:.2f}, r^2 = {r_value**2:.5f}")
plt.legend()
plt.xlabel("Voltage (V)")
plt.ylabel("Magnetic Flux Density (G)")
# Out:
# 1.853947374560473 -1.1992972765978571 0.9997368981403403 2.4646818839609582e-57 0.007294921307464304
# Text(0, 0.5, 'Magnetic Flux Density (G)')

# %%
# converts volts to gauss using fitted regression line from calibration data
# does not modify original data
def volts_to_gauss(volts):
    slope = 1.85
    intercept = -1.20
    gauss = slope*volts.copy() + intercept
    return gauss

# %%
df = pd.read_csv(r"C:\Users\gxlab\Code\MOKE\data\2025-07-21_11-09-05\H+_data.csv", comment="#")
df
# Out:
#      Voltage (V)  Current (A)  Average Intensity  Total Intensity  SNR (dB)
# 0      -0.010155     0.000012           9.091429            60458  8.953867
# 1       0.490566     0.009859           9.119248            60643  8.967618
# 2       0.990293     0.019784           9.125414            60684  8.939781
# 3       1.489906     0.029663           9.080451            60385  8.929778
# 4       1.989661     0.039478           9.059850            60248  8.941254
# ..           ...          ...                ...              ...       ...
# 253    23.494970     0.449867           9.018045            59970  8.991772
# 254    23.995730     0.459098           9.048571            60173  9.022794
# 255    24.495360     0.468583           9.030827            60055  8.963657
# 256    24.995330     0.477747           9.001353            59859  8.967845
# 257    25.495080     0.486745           9.034436            60079  9.023697
#
# [258 rows x 5 columns]

# %%
fig, ax = plt.subplots()
ax.plot(volts_to_gauss(df["Voltage (V)"]), df["Average Intensity"])
ax.set_title("Average Intensity vs Applied Voltage for P-Polarized Incident Light")
ax.set_xlabel("H field (Oe)")  # since it's measured in air, the permeability is about 1 so gauss to Oe is 1-to-1
ax.set_ylabel("Average Intensity (Counts)")
fig.text(0.5, -0.05, 'Figure 2: Hysteresis measurement using p-polarized light.\nThe analyzer is set 2 pm 0.5 degree counterclockwise off extinction.', ha='center', fontsize=10)
# Out:
# Text(0.5, -0.05, 'Figure 2: Hysteresis measurement using p-polarized light.\nThe analyzer is set 2 pm 0.5 degree counterclockwise off extinction.')

# %%
df = pd.read_csv(r"C:\Users\gxlab\Code\MOKE\data\2025-07-21_12-34-02\H+_data.csv", comment="#")
df
# Out:
#      Voltage (V)  Current (A)  Average Intensity  Total Intensity  SNR (dB)
# 0      -0.010135     0.000009          13.392549            68302  9.790880
# 1       0.490602     0.009646          13.471765            68706  9.692712
# 2       0.990137     0.019281          13.342157            68045  9.806254
# 3       1.489766     0.028905          13.367647            68175  9.707049
# 4       1.989635     0.038537          13.413725            68410  9.852558
# ..           ...          ...                ...              ...       ...
# 253    23.495160     0.444359          13.338627            68027  9.799369
# 254    23.995850     0.453198          13.258235            67617  9.876170
# 255    24.495510     0.462154          13.211176            67377  9.841444
# 256    24.995300     0.471151          13.296863            67814  9.823526
# 257    25.495100     0.480280          13.237647            67512  9.858679
#
# [258 rows x 5 columns]

# %%
fig, ax = plt.subplots()
ax.plot(volts_to_gauss(df["Voltage (V)"]), df["Average Intensity"])
ax.set_title("Average Intensity vs H field for P-Polarized Incident Light")
ax.set_xlabel("H field (Oe)")  # since it's measured in air, the permeability is about 1 so gauss to Oe is 1-to-1
ax.set_ylabel("Average Intensity (Counts)")
fig.text(0.5, -0.05, 'Figure 2: Hysteresis measurement using p-polarized light.\nThe analyzer is set 3 pm 0.5 degree counterclockwise off extinction.', ha='center', fontsize=10)
# Out:
# Text(0.5, -0.05, 'Figure 2: Hysteresis measurement using p-polarized light.\nThe analyzer is set 3 pm 0.5 degree counterclockwise off extinction.')

# %%
df = pd.read_csv(r"C:\Users\gxlab\Code\MOKE\data\2025-07-21_12-55-48\data_2025-07-21_12-55-48.csv", comment="#")
df
# Out:
#      Voltage (V)  Current (A)  Average Intensity  Total Intensity  SNR (dB)
# 0      -0.010113     0.000011          18.864118            96207  9.002928
# 1       0.490535     0.009507          18.867451            96224  9.022558
# 2       0.990208     0.019100          18.816078            95962  9.044757
# 3       1.489756     0.028554          18.825294            96009  9.085028
# 4       1.989676     0.038177          18.787255            95815  9.013399
# ..           ...          ...                ...              ...       ...
# 253    23.489980     0.000205          20.085294           102435  9.012977
# 254    23.990760     0.000203          20.191961           102979  8.954770
# 255    24.490470     0.000203          20.146667           102748  8.975220
# 256    24.990260     0.000207          20.108627           102554  9.010667
# 257    25.490230     0.000206          20.190000           102969  9.008065
#
# [258 rows x 5 columns]

# %%
fig, ax = plt.subplots()
ax.plot(volts_to_gauss(df["Voltage (V)"]), df["Average Intensity"])
ax.set_title("Average Intensity vs H field for P-Polarized Incident Light")
ax.set_xlabel("H field (Oe)")  # since it's measured in air, the permeability is about 1 so gauss to Oe is 1-to-1
ax.set_ylabel("Average Intensity (Counts)")
fig.text(0.5, -0.05, 'Figure 2: Hysteresis measurement using p-polarized light.\nThe analyzer is set 4 pm 0.5 degree counterclockwise off extinction.', ha='center', fontsize=10)
# Out:
# Text(0.5, -0.05, 'Figure 2: Hysteresis measurement using p-polarized light.\nThe analyzer is set 4 pm 0.5 degree counterclockwise off extinction.')

# %%
df_dict = {}
paths = (r"C:\Users\gxlab\Code\MOKE\data\2025-07-17_14-56-28\H+_data.csv", r"C:\Users\gxlab\Code\MOKE\data\2025-07-21_11-09-05\H+_data.csv", r"C:\Users\gxlab\Code\MOKE\data\2025-07-21_12-34-02\H+_data.csv", r"C:\Users\gxlab\Code\MOKE\data\2025-07-21_12-55-48\data_2025-07-21_12-55-48.csv")
for i, path in enumerate(paths):
    df_dict[f"{i+1} deg off extinction"] = pd.read_csv(path, comment="#")

df_dict
# Out:
# {'1 deg off extinction':      Voltage (V)  Current (A)  Average Intensity  Total Intensity   SNR (dB)
#  0      -0.010159     0.000007           6.747733            50608   9.957298
#  1       0.490520     0.009765           6.757867            50684   9.977843
#  2       0.990297     0.019576           6.763467            50726  10.011707
#  3       1.489965     0.029364           6.742133            50566   9.968347
#  4       1.989816     0.039052           6.741467            50561  10.006923
#  ..           ...          ...                ...              ...        ...
#  353    33.495270     0.604985           6.642533            49819  10.046836
#  354    33.994970     0.617244           6.674000            50055  10.029278
#  355    34.495600     0.624481           6.671200            50034  10.046481
#  356    34.995530     0.634574           6.657200            49929  10.047696
#  357    35.495000     0.642565           6.661467            49961  10.047941
#
# ...

# %%
fig, ax = plt.subplots(2, 2, figsize=(10, 7))
ax = ax.flatten()
for i, (key, df) in enumerate(df_dict.items()):
    ax[i].plot(volts_to_gauss(df["Voltage (V)"]), df["Average Intensity"])
    ax[i].set_title(key)
    ax[i].set_xlabel("Magnetic field (G)")
    ax[i].set_ylabel("Avg Intensity (Counts)")
fig.suptitle("Hysteresis Loops for Incident P-Polarized Light")
fig.tight_layout()

# %%
df = df_dict["4 deg off extinction"]
def analysis(df):
    n = len(df["Voltage (V)"])
    x = df["Voltage (V)"]
    I0 = df["Average Intensity"][0]
    y = df["Average Intensity"]
    plt.plot(x, y)
    pos_sweep_avg_I = y[0:2*n//5].mean()
    neg_sweep_avg_I = y[2*n//5:4*n//5].mean()
    total_avg = y[0:4*n//5].mean()
    volts = np.arange(-35, 35, 0.5)
    plt.plot(volts, np.full_like(volts, pos_sweep_avg_I))
    plt.plot(volts, np.full_like(volts, neg_sweep_avg_I))
    plt.plot(volts, np.full_like(volts, I0))
    plt.plot(volts, np.full_like(volts, total_avg))
    percent_change_I = 100*(neg_sweep_avg_I - pos_sweep_avg_I)/I0
    print(f"I_0: {I0:.3f}")
    print(f"Low I: {pos_sweep_avg_I:.3f}")
    print(f"High I: {neg_sweep_avg_I:.3f}")
    print(f"Average I: {total_avg:.3f}")
    print(f"Discrepency between I_0 and Average I: {100*(total_avg-I0)/I0:.3f} %")
    print(f"Percent change in intensity: {percent_change_I:.3f} %")
analysis(df)
# Out:
# I_0: 18.864
# Low I: 18.993
# High I: 20.044
# Average I: 19.518
# Discrepency between I_0 and Average I: 3.468 %
# Percent change in intensity: 5.571 %

# %%
df = pd.read_csv(r"C:\Users\gxlab\Code\MOKE\data\2025-07-24_17-20-27_after_clean_142deg_4ms\data_2025-07-24_17-20-27.csv", comment="#")
df
# Out:
#      Voltage (V)  Current (A)  Average Intensity  Total Intensity  SNR (dB)
# 0      -0.009900     0.000005          10.153636            44676  8.192861
# 1       0.240117     0.004842          10.202727            44892  8.169480
# 2       0.490746     0.009712          10.110682            44487  8.263527
# 3       0.739933     0.014547          10.087955            44387  8.264224
# 4       0.990420     0.019413          10.093182            44410  8.284684
# ..           ...          ...                ...              ...       ...
# 295    13.744100     0.264419           9.859091            43380  8.373196
# 296    13.994930     0.269250           9.779318            43029  8.436595
# 297    14.244080     0.273674           9.810455            43166  8.429601
# 298    14.494760     0.278770           9.852727            43352  8.374253
# 299    14.745120     0.283252           9.779091            43028  8.459586
#
# [300 rows x 5 columns]

# %%
fig, ax = plt.subplots()
n = len(df["Voltage (V)"])
ax.plot(volts_to_gauss(df["Voltage (V)"][0:2*n//5]), df["Average Intensity"][0:2*n//5], label="sweep 1")
ax.plot(volts_to_gauss(df["Voltage (V)"][2*n//5:4*n//5]), df["Average Intensity"][2*n//5:4*n//5], label="sweep 2")
ax.plot(volts_to_gauss(df["Voltage (V)"][4*n//5:n]), df["Average Intensity"][4*n//5:n], label="sweep 3")
ax.legend()
ax.set_title("Average Intensity vs Applied Magnetic Field for P-Polarized Incident Light")
ax.set_xlabel("H field (Oe)")  # since it's measured in air, the permeability is about 1 so gauss to Oe is 1-to-1
ax.set_ylabel("Average Intensity (Counts)")
# Out:
# Text(0, 0.5, 'Average Intensity (Counts)')

# %%
df = pd.read_csv(r"data\2025-07-28_11-39-29\data_2025-07-28_11-39-29.csv", comment="#")
fig, ax = plt.subplots()
n = len(df["Voltage (V)"])
ax.plot(volts_to_gauss(df["Voltage (V)"][0:2*n//5]), df["Average Intensity"][0:2*n//5], label="sweep 1")
ax.plot(volts_to_gauss(df["Voltage (V)"][2*n//5:4*n//5]), df["Average Intensity"][2*n//5:4*n//5], label="sweep 2")
ax.plot(volts_to_gauss(df["Voltage (V)"][4*n//5:n]), df["Average Intensity"][4*n//5:n], label="sweep 3")
ax.legend()
ax.set_title("Average Intensity vs Applied Magnetic Field for P-Polarized Incident Light")
ax.set_xlabel("H field (Oe)")  # since it's measured in air, the permeability is about 1 so gauss to Oe is 1-to-1
ax.set_ylabel("Average Intensity (Counts)")
print(df["Average Intensity"][0])
# Out:
# 10.000196078431372

# %%
df = pd.read_csv(r"data\2025-07-28_11-56-04\data_2025-07-28_11-56-04.csv", comment="#")
fig, ax = plt.subplots()
n = len(df["Voltage (V)"])
ax.plot(volts_to_gauss(df["Voltage (V)"][0:2*n//5]), df["Average Intensity"][0:2*n//5], label="sweep 1")
ax.plot(volts_to_gauss(df["Voltage (V)"][2*n//5:4*n//5]), df["Average Intensity"][2*n//5:4*n//5], label="sweep 2")
ax.plot(volts_to_gauss(df["Voltage (V)"][4*n//5:n]), df["Average Intensity"][4*n//5:n], label="sweep 3")
ax.legend()
ax.set_title("Average Intensity vs Applied Magnetic Field for P-Polarized Incident Light")
ax.set_xlabel("H field (Oe)")  # since it's measured in air, the permeability is about 1 so gauss to Oe is 1-to-1
ax.set_ylabel("Average Intensity (Counts)")
print(df["Average Intensity"][0])
# Out:
# 10.021764705882353

# %%
from matplotlib.collections import LineCollection
from matplotlib.colors import Normalize
import matplotlib.cm as cm
# Helper function: create color-gradient line segments
def colored_line(ax, x, y, cmap='viridis'):
    points = np.array([x, y]).T.reshape(-1, 1, 2)
    segments = np.concatenate([points[:-1], points[1:]], axis=1)
    t = np.linspace(0, 1, len(x))  # time-normalized
    norm = Normalize(0, 1)
    lc = LineCollection(segments, cmap=cmap, norm=norm)
    lc.set_array(t)
    lc.set_linewidth(2)
    line = ax.add_collection(lc)
    return line

# %%
df_dict = {}
names = ("Dither only", "Diffuse Only", "Dither & Diffuse")
paths = (
    r"data\2025-07-28_12-03-32_no_diffuse\data_2025-07-28_12-03-32.csv", 
    r"data\2025-07-28_11-56-04_no_dither\data_2025-07-28_11-56-04.csv", 
    r"data\2025-07-28_11-39-29_dither_and_diffuse\data_2025-07-28_11-39-29.csv"
)

for name, path in zip(names, paths):
    df_dict[name] = pd.read_csv(path, comment="#")

fig, ax = plt.subplots(1, 3, figsize=(15, 5))
ax = ax.flatten()
for i, (key, df) in enumerate(df_dict.items()):
    ax[i].plot(volts_to_gauss(df["Voltage (V)"][0:2*n//5]), df["Average Intensity"][0:2*n//5], label="sweep 1")
    ax[i].plot(volts_to_gauss(df["Voltage (V)"][2*n//5 - 1:4*n//5]), df["Average Intensity"][2*n//5 - 1:4*n//5], label="sweep 2")
    ax[i].plot(volts_to_gauss(df["Voltage (V)"][4*n//5 - 1:n]), df["Average Intensity"][4*n//5 - 1:n], label="sweep 3", color="tab:red")
    ax[i].set_title(key)
    ax[i].set_xlabel("Magnetic field (G)")
    ax[i].set_ylabel("Avg Intensity (Counts)")
    ax[i].legend()
fig.suptitle("Hysteresis Loops for Incident P-Polarized Light")
fig.text(0.5, -0.05, "Comparison of despeckling methods. 2 pm 0.5 degrees off extinction, 4 ms exposure time, \n15 frames averaged for all plots. Dithering settings are 240 Hz at 250 mVpp.", ha="center")
fig.tight_layout()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection
from matplotlib.colors import LinearSegmentedColormap, Normalize
import matplotlib.cm as cm

# ["#5ebcff", "#082a42"] blue gradient
color_map = LinearSegmentedColormap.from_list("custom_gray_gold", ["#40b3ff", "#082a42"])
# Helper function: draw a color-gradient line using LineCollection
def colored_line(ax, x, y, cmap=color_map):
    points = np.array([x, y]).T.reshape(-1, 1, 2)
    segments = np.concatenate([points[:-1], points[1:]], axis=1)
    t = np.linspace(0, 1, len(x))  # normalized "time"
    norm = Normalize(0, 1)
    lc = LineCollection(segments, cmap=cmap, norm=norm)
    lc.set_array(t)
    lc.set_linewidth(2)
    ax.add_collection(lc)
    return lc

# Volts to gauss conversion
def volts_to_gauss(volts):
    return 1.85 * volts - 1.20

# Load data
df_dict = {}
names = ("Dither only", "Diffuse Only", "Dither & Diffuse")
paths = (
    r"data\2025-07-28_12-03-32_no_diffuse\data_2025-07-28_12-03-32.csv",
    r"data\2025-07-28_11-56-04_no_dither\data_2025-07-28_11-56-04.csv",
    r"data\2025-07-28_11-39-29_dither_and_diffuse\data_2025-07-28_11-39-29.csv"
)

for name, path in zip(names, paths):
    df_dict[name] = pd.read_csv(path, comment="#")

# Setup plots
fig, ax = plt.subplots(1, 3, figsize=(15, 5))
ax = ax.flatten()

cbar_ref = None  # To link a colorbar to one line collection

for i, (key, df) in enumerate(df_dict.items()):
    n = len(df)
    B = volts_to_gauss(df["Voltage (V)"])
    I = df["Average Intensity"]

    lc = colored_line(ax[i], B, I)
    if cbar_ref is None:
        cbar_ref = lc  # Only need one reference for shared colorbar

    ax[i].set_title(key)
    ax[i].set_xlabel("Magnetic field (G)")
    ax[i].set_ylabel("Avg Intensity (Counts)")
    ax[i].autoscale() 

fig.suptitle("Hysteresis Loops for Incident P-Polarized Light")
fig.text(
    0.5, -0.2,
    "Comparison of despeckling methods. 2 ± 0.5° off extinction, 4 ms exposure, 15-frame average.\nDithering: 240 Hz at 250 mVpp.",
    ha="center"
)
fig.tight_layout()
# Place a horizontal colorbar below the subplots
cbar_ax = fig.add_axes([0.25, 0, 0.5, 0.02])  # [left, bottom, width, height]
fig.colorbar(cbar_ref, cax=cbar_ax, orientation='horizontal', label="Relative Time in Sweep")
